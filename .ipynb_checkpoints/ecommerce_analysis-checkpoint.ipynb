# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import sqlite3

print("Kütüphaneler yüklendi ✅")
# Out:
# Kütüphaneler yüklendi ✅

# %%
df = pd.read_csv(r'C:\Users\Cagatay\Desktop\project\ecommerce-sql-analysis\data\online_retail_II.csv', encoding='latin-1')

print("Veri yüklendi ✅")
print(f"Satır sayısı: {df.shape[0]}")
print(f"Sütun sayısı: {df.shape[1]}")
# Out:
# Veri yüklendi ✅
# Satır sayısı: 1067371
# Sütun sayısı: 8

# %%
df.head()
# Out:
#   Invoice StockCode                          Description  Quantity  \
# 0  489434     85048  15CM CHRISTMAS GLASS BALL 20 LIGHTS        12
# 1  489434    79323P                   PINK CHERRY LIGHTS        12
# 2  489434    79323W                  WHITE CHERRY LIGHTS        12
# 3  489434     22041         RECORD FRAME 7" SINGLE SIZE         48
# 4  489434     21232       STRAWBERRY CERAMIC TRINKET BOX        24
#
#            InvoiceDate  Price  Customer ID         Country
# 0  2009-12-01 07:45:00   6.95      13085.0  United Kingdom
# 1  2009-12-01 07:45:00   6.75      13085.0  United Kingdom
# 2  2009-12-01 07:45:00   6.75      13085.0  United Kingdom
# 3  2009-12-01 07:45:00   2.10      13085.0  United Kingdom
# 4  2009-12-01 07:45:00   1.25      13085.0  United Kingdom

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 1067371 entries, 0 to 1067370
# Data columns (total 8 columns):
#  #   Column       Non-Null Count    Dtype
# ---  ------       --------------    -----
#  0   Invoice      1067371 non-null  str
#  1   StockCode    1067371 non-null  str
#  2   Description  1062989 non-null  str
#  3   Quantity     1067371 non-null  int64
#  4   InvoiceDate  1067371 non-null  str
#  5   Price        1067371 non-null  float64
#  6   Customer ID  824364 non-null   float64
#  7   Country      1067371 non-null  str
# dtypes: float64(2), int64(1), str(5)
# memory usage: 65.1 MB

# %%
missing = df.isnull().sum()
missing_percent = (df.isnull().sum() / len(df)) * 100

missing_df = pd.DataFrame({
    'Eksik Sayı': missing,
    'Eksik Yüzde (%)': missing_percent.round(2)
})

print(missing_df)
# Out:
#              Eksik Sayı  Eksik Yüzde (%)
# Invoice               0             0.00
# StockCode             0             0.00
# Description        4382             0.41
# Quantity              0             0.00
# InvoiceDate           0             0.00
# Price                 0             0.00
# Customer ID      243007            22.77
# Country               0             0.00

# %%
# Invoice'u C ile başlayanlar iptal edilmiş siparişler
print(f"İptal öncesi: {df.shape[0]} satır")

df = df[~df['Invoice'].str.startswith('C')]

print(f"İptal sonrası: {df.shape[0]} satır")
print(f"Çıkarılan iptal: {824364 - df.shape[0]}")
# Out:
# İptal öncesi: 1067371 satır
# İptal sonrası: 1047877 satır
# Çıkarılan iptal: -223513

# %%
df['Revenue'] = df['Quantity'] * df['Price']

print(f"Revenue sütunu eklendi ✅")
print(df[['Invoice', 'Quantity', 'Price', 'Revenue']].head())
# Out:
# Revenue sütunu eklendi ✅
#   Invoice  Quantity  Price  Revenue
# 0  489434        12   6.95     83.4
# 1  489434        12   6.75     81.0
# 2  489434        12   6.75     81.0
# 3  489434        48   2.10    100.8
# 4  489434        24   1.25     30.0

# %%
# SQLite database oluştur
conn = sqlite3.connect('ecommerce.db')

# Veriyi database'e yükle
df.to_sql('orders', conn, if_exists='replace', index=False)

print("Database oluşturuldu ✅")
print("Tablo adı: orders")
# Out:
# Database oluşturuldu ✅
# Tablo adı: orders

# %%
# SQL sorgusu çalıştır
query = """
SELECT COUNT(*) as toplam_satir
FROM orders
"""

result = pd.read_sql_query(query, conn)
print(result)
# Out:
#    toplam_satir
# 0       1047877

# %%
query = """
SELECT "Customer ID",
       ROUND(SUM(Revenue), 2) as total_revenue,
       COUNT(DISTINCT Invoice) as total_orders
FROM orders
GROUP BY "Customer ID"
ORDER BY total_revenue DESC
LIMIT 10
"""

result = pd.read_sql_query(query, conn)
print(result)
# Out:
#    Customer ID  total_revenue  total_orders
# 0          NaN     3070489.25          8361
# 1      18102.0      608821.65           145
# 2      14646.0      528602.52           152
# 3      14156.0      313946.37           156
# 4      14911.0      295972.63           398
# 5      17450.0      246973.09            51
# 6      13694.0      196482.81           143
# 7      17511.0      175603.55            60
# 8      16446.0      168472.50             2
# 9      16684.0      147142.77            55

# %%
query = """
SELECT SUBSTR(InvoiceDate, 1, 7) as month,
       ROUND(SUM(Revenue), 2) as monthly_revenue,
       COUNT(DISTINCT Invoice) as order_count
FROM orders
GROUP BY month
ORDER BY month
"""

result_monthly = pd.read_sql_query(query, conn)
print(result_monthly)
# Out:
#       month  monthly_revenue  order_count
# 0   2009-12        825685.76         1929
# 1   2010-01        652708.50         1333
# 2   2010-02        553339.74         1729
# 3   2010-03        833570.13         1960
# 4   2010-04        627934.63         1588
# 5   2010-05        659858.86         2011
# 6   2010-06        752270.14         1859
# 7   2010-07        606681.15         1673
# 8   2010-08        697274.91         1604
# 9   2010-09        924333.01         2004
# 10  2010-10       1126558.04         2489
# 11  2010-11       1470272.48         3093
# 12  2010-12       1262598.79         1699
# 13  2011-01        691364.56         1216
# 14  2011-02        523631.89         1174
# 15  2011-03        717639.36         1665
# 16  2011-04        537808.62         1504
# 17  2011-05        770536.02         1848
# 18  2011-06        761739.90         1683
# 19  2011-07        719221.19         1657
# 20  2011-08        737014.26         1459
# 21  2011-09       1058590.17         1994
# 22  2011-10       1154979.30         2275
# 23  2011-11       1509496.33         3021
# 24  2011-12        638810.68          869

# %%
query = """
SELECT Country,
       ROUND(SUM(Revenue), 2) as total_revenue,
       COUNT(DISTINCT "Customer ID") as customer_count
FROM orders
GROUP BY Country
ORDER BY total_revenue DESC
LIMIT 10
"""

result_country = pd.read_sql_query(query, conn)
print(result_country)
# Out:
#           Country  total_revenue  customer_count
# 0  United Kingdom    17712301.64            5353
# 1            EIRE      664431.78               5
# 2     Netherlands      554232.34              22
# 3         Germany      431262.46             107
# 4          France      356944.60              95
# 5       Australia      169968.11              15
# 6           Spain      109178.53              41
# 7     Switzerland      101011.29              22
# 8          Sweden       91903.72              19
# 9         Denmark       69862.19              12

# %%
query = """
SELECT Description,
       SUM(Quantity) as total_quantity,
       ROUND(SUM(Revenue), 2) as total_revenue
FROM orders
GROUP BY Description
ORDER BY total_quantity DESC
LIMIT 10
"""

result_products = pd.read_sql_query(query, conn)
print(result_products)
# Out:
#                           Description  total_quantity  total_revenue
# 0   WORLD WAR 2 GLIDERS ASSTD DESIGNS          110249       25259.90
# 1  WHITE HANGING HEART T-LIGHT HOLDER           96688      266923.55
# 2       ASSORTED COLOUR BIRD ORNAMENT           81817      132187.92
# 3         PAPER CRAFT , LITTLE BIRDIE           80995      168469.60
# 4             JUMBO BAG RED RETROSPOT           79285      150935.56
# 5      MEDIUM CERAMIC TOP STORAGE JAR           78033       81700.92
# 6                 BROCADE RING PURSE            71440       14959.19
# 7  PACK OF 60 PINK PAISLEY CAKE CASES           56794       28490.98
# 8         60 TEATIME FAIRY CAKE CASES           54716       27404.22
# 9                SMALL POPCORN HOLDER           49984       44090.13

# %%
plt.figure(figsize=(14, 6))

plt.plot(result_monthly['month'], 
         result_monthly['monthly_revenue'], 
         marker='o', 
         color='steelblue',
         linewidth=2)

plt.title('Aylık Revenue Trendi', fontsize=16)
plt.xlabel('Ay')
plt.ylabel('Revenue (£)')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
result_country_no_uk = result_country[result_country['Country'] != 'United Kingdom']

plt.figure(figsize=(12, 7))

sns.barplot(data=result_country_no_uk, 
            x='Country', 
            y='total_revenue',
            hue='Country',
            legend=False)

plt.title('Ülke Bazında Revenue (UK Hariç)', fontsize=16)
plt.xlabel('Ülke')
plt.ylabel('Revenue (£)')
plt.xticks(rotation=45, ha='right')
plt.subplots_adjust(bottom=0.25)
plt.show()

# %%
query = """
SELECT 
    "Customer ID",
    ROUND(julianday('2011-12-31') - julianday(MAX(InvoiceDate)), 0) as recency,
    COUNT(DISTINCT Invoice) as frequency,
    ROUND(SUM(Revenue), 2) as monetary
FROM orders
GROUP BY "Customer ID"
ORDER BY monetary DESC
LIMIT 20
"""

result_rfm = pd.read_sql_query(query, conn)
print(result_rfm)
# Out:
#     Customer ID  recency  frequency    monetary
# 0           NaN     22.0       8361  3070489.25
# 1       18102.0     22.0        145   608821.65
# 2       14646.0     22.0        152   528602.52
# 3       14156.0     31.0        156   313946.37
# 4       14911.0     22.0        398   295972.63
# 5       17450.0     29.0         51   246973.09
# 6       13694.0     25.0        143   196482.81
# 7       17511.0     24.0         60   175603.55
# 8       16446.0     22.0          2   168472.50
# 9       16684.0     25.0         55   147142.77
# 10      12415.0     45.0         28   144458.37
# 11      15061.0     24.0        127   137818.52
# 12      16029.0     60.0        107   122209.14
# 13      17949.0     22.0        118   118628.08
# 14      15311.0     22.0        208   116771.16
# 15      13089.0     24.0        203   116737.86
# 16      12931.0     42.0         57    92347.34
# 17      14298.0     29.0         82    91194.49
# 18      15769.0     28.0         46    88704.32
# 19      12346.0    347.0         12    77556.46
